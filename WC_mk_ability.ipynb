# %%
#==================================================================================================================#
#This code is to generate the ability_18/22.csv file, which contains all the fifa 18/22 career mode player data 
#The files used in the code are player_18/22.csv (encodeing=UTF-8).
#==================================================================================================================#

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
players=pd.read_csv("players_18.csv",encoding="UTF-8")                 #remember to change the file
players=players.drop(columns=['release_clause_eur','club_contract_valid_until','club_joined','nation_jersey_number','nation_position','nation_team_id','club_loaned_from','nation_jersey_number','body_type','real_face','player_tags','player_traits','sofifa_id','player_face_url', 'club_logo_url','club_flag_url', 'nation_logo_url', 'nation_flag_url'])
display(players)                              #gk沒有pace shooting passing dribbling defending physic 有 goalkeeping_speed
print(players.isnull().sum())
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_26104\1284345836.py:1: DtypeWarning: Columns (81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   players=pd.read_csv("players_18.csv",encoding="UTF-8")                 #remember to change the file
#                                               player_url         short_name  \
# 0      https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 1      https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 2      https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# 3      https://sofifa.com/player/176580/luis-suarez/1...          L. Suárez
# 4      https://sofifa.com/player/190871/neymar-da-sil...             Neymar
# ...                                                  ...                ...
# 17949  https://sofifa.com/player/235352/tommy-kassemo...       T. Käßemodel
# 17950  https://sofifa.com/player/237463/adam-kelsey/1...          A. Kelsey
# ...

# %%
for i in range(0,17954,1):                             #if year is 2022 please change 17954 to 19238
    name=players['player_url'].iloc[i]
    name=name.split("/")[-2].replace("-"," ")
    players['player_url'].iloc[i]=name
print(players["player_url"])
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_26104\3407753397.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['player_url'].iloc[i]=name
# 0        c ronaldo dos santos aveiro
# 1                       lionel messi
# 2                       manuel neuer
# 3                        luis suarez
# 4          neymar da silva santos jr
#                     ...
# 17949               tommy kassemodel
# 17950                    adam kelsey
# 17951                  leslie sackey
# 17952                 josh lundstram
# 17953                    jack keeble
# Name: player_url, Length: 17954, dtype: object

# %%
ability_label=['player_url' ,'overall'
 , 'age' , 'height_cm', 'weight_kg'
 , 'skill_moves', 'pace',
 'shooting', 'passing', 'dribbling' ,'defending', 'physic',
 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy',
 'attacking_short_passing', 'attacking_volleys' ,'skill_dribbling',
 'skill_curve', 'skill_fk_accuracy' ,'skill_long_passing',
 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
 'movement_agility', 'movement_reactions', 'movement_balance',
 'power_shot_power' ,'power_jumping', 'power_stamina', 'power_strength',
 'power_long_shots', 'mentality_aggression' ,'mentality_interceptions',
 'mentality_positioning', 'mentality_vision' ,'mentality_penalties',
 'mentality_composure' ,'defending_marking_awareness',
 'defending_standing_tackle' ,'defending_sliding_tackle',
 'goalkeeping_diving', 'goalkeeping_handling' ,'goalkeeping_kicking',
 'goalkeeping_positioning' ,'goalkeeping_reflexes', 'goalkeeping_speed']
ability=players[ability_label].fillna(0)
display(ability.isnull().sum())
ability=ability.rename(columns={"player_url":"long_name"})
display(ability)
#ability.to_csv('ability_"year".csv')                 #save the file
# Out:
# player_url                     0
# overall                        0
# age                            0
# height_cm                      0
# weight_kg                      0
# skill_moves                    0
# pace                           0
# shooting                       0
# passing                        0
# dribbling                      0
# defending                      0
# physic                         0
# attacking_crossing             0
# attacking_finishing            0
# attacking_heading_accuracy     0
# attacking_short_passing        0
# attacking_volleys              0
# skill_dribbling                0
# skill_curve                    0
# skill_fk_accuracy              0
# skill_long_passing             0
# skill_ball_control             0
# movement_acceleration          0
# movement_sprint_speed          0
# movement_agility               0
# movement_reactions             0
# movement_balance               0
# power_shot_power               0
# ...
